# %%
# Import the dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import requests
from datetime import datetime
from citipy import citipy
import json
import time
from scipy.stats import linregress

# Import Gmaps and Requests dependencies.
import gmaps
import requests

# Import the API key.
from config import weather_api_key
from config import g_key

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Create a list for holding the cities.
cities = []

# Identify the nearest city for each latitude and longitude combination.
for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name

    # If the city is unique, then we will add it to the cities list.
    if city not in cities:
        cities.append(city)
# Print the city count to confirm sufficient count.
len(cities)
# Out:
# 752

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&appid=" + weather_api_key


# Create an empty list to hold the weather data.
city_data = []

# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in the list.
for i, city in enumerate(cities):

    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
    

    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    # Add 1 to the record count.
    record_count += 1
    
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    # Run an API request for each of the cities.
    
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        weather_description = city_weather["weather"][0]["description"]

        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Country": city_country,
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          #"Date": city_date}
                          "Current Description": weather_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | jamestown
# Processing Record 2 of Set 1 | iqaluit
# Processing Record 3 of Set 1 | guaruja
# Processing Record 4 of Set 1 | bredasdorp
# Processing Record 5 of Set 1 | vaini
# Processing Record 6 of Set 1 | mitsamiouli
# Processing Record 7 of Set 1 | leningradskiy
# Processing Record 8 of Set 1 | new norfolk
# Processing Record 9 of Set 1 | shimoda
# Processing Record 10 of Set 1 | praia da vitoria
# Processing Record 11 of Set 1 | atuona
# Processing Record 12 of Set 1 | hithadhoo
# Processing Record 13 of Set 1 | attawapiskat
# City not found. Skipping...
# Processing Record 14 of Set 1 | qaanaaq
# Processing Record 15 of Set 1 | ancud
# Processing Record 16 of Set 1 | hilo
# Processing Record 17 of Set 1 | arraial do cabo
# Processing Record 18 of Set 1 | palabuhanratu
# City not found. Skipping...
# Processing Record 19 of Set 1 | yellowknife
# Processing Record 20 of Set 1 | mataura
# Processing Record 21 of Set 1 | ushuaia
# Processing Record 22 of Set 1 | hecun
# Processing Record 23 of Set 1 | jiwani
# Processing Record 24 of Set 1 | taolanaro
# City not found. Skipping...
# Processing Record 25 of Set 1 | ostrovnoy
# Processing Record 26 of Set 1 | ulladulla
# Processing Record 27 of Set 1 | albany
# Processing Record 28 of Set 1 | faanui
# Processing Record 29 of Set 1 | nizhneyansk
# City not found. Skipping...
# Processing Record 30 of Set 1 | tokur
# Processing Record 31 of Set 1 | san quintin
# Processing Record 32 of Set 1 | banda aceh
# Processing Record 33 of Set 1 | daman
# Processing Record 34 of Set 1 | puntarenas
# Processing Record 35 of Set 1 | byron bay
# Processing Record 36 of Set 1 | poso
# Processing Record 37 of Set 1 | saint george
# Processing Record 38 of Set 1 | atar
# Processing Record 39 of Set 1 | kidal
# Processing Record 40 of Set 1 | chicama
# Processing Record 41 of Set 1 | mount gambier
# Processing Record 42 of Set 1 | kondinskoye
# Processing Record 43 of Set 1 | grand gaube
# Processing Record 44 of Set 1 | asahikawa
# Processing Record 45 of Set 1 | punta arenas
# Processing Record 46 of Set 1 | avarua
# Processing Record 47 of Set 1 | rikitea
# Processing Record 48 of Set 1 | tulagi
# Processing Record 49 of Set 1 | bowling green
# Processing Record 50 of Set 1 | lichinga
# Processing Record 1 of Set 2 | broome
# Processing Record 2 of Set 2 | torbay
# Processing Record 3 of Set 2 | sedelnikovo
# City not found. Skipping...
# Processing Record 4 of Set 2 | kyzyl-suu
# Processing Record 5 of Set 2 | katsuura
# Processing Record 6 of Set 2 | vila velha
# Processing Record 7 of Set 2 | maun
# Processing Record 8 of Set 2 | belushya guba
# City not found. Skipping...
# Processing Record 9 of Set 2 | puerto baquerizo moreno
# Processing Record 10 of Set 2 | victoria
# Processing Record 11 of Set 2 | bluff
# Processing Record 12 of Set 2 | tumannyy
# City not found. Skipping...
# Processing Record 13 of Set 2 | yarmouth
# Processing Record 14 of Set 2 | port lincoln
# Processing Record 15 of Set 2 | klaksvik
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | karaul
# City not found. Skipping...
# Processing Record 18 of Set 2 | buala
# Processing Record 19 of Set 2 | geraldton
# Processing Record 20 of Set 2 | sambava
# Processing Record 21 of Set 2 | camiri
# Processing Record 22 of Set 2 | kodiak
# Processing Record 23 of Set 2 | mar del plata
# Processing Record 24 of Set 2 | lakes entrance
# Processing Record 25 of Set 2 | hofn
# Processing Record 26 of Set 2 | ahipara
# Processing Record 27 of Set 2 | georgetown
# Processing Record 28 of Set 2 | balikpapan
# Processing Record 29 of Set 2 | sentyabrskiy
# City not found. Skipping...
# Processing Record 30 of Set 2 | la orilla
# Processing Record 31 of Set 2 | nenjiang
# Processing Record 32 of Set 2 | samusu
# City not found. Skipping...
# Processing Record 33 of Set 2 | kimbe
# Processing Record 34 of Set 2 | bend
# Processing Record 35 of Set 2 | cumaribo
# City not found. Skipping...
# Processing Record 36 of Set 2 | xuddur
# Processing Record 37 of Set 2 | bahia honda
# Processing Record 38 of Set 2 | pedernales
# Processing Record 39 of Set 2 | isangel
# Processing Record 40 of Set 2 | norman wells
# Processing Record 41 of Set 2 | hermanus
# Processing Record 42 of Set 2 | vao
# Processing Record 43 of Set 2 | buchanan
# Processing Record 44 of Set 2 | puerto ayora
# Processing Record 45 of Set 2 | cabedelo
# Processing Record 46 of Set 2 | hobart
# Processing Record 47 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 48 of Set 2 | cape town
# Processing Record 49 of Set 2 | scarborough
# Processing Record 50 of Set 2 | guerrero negro
# Processing Record 1 of Set 3 | busselton
# Processing Record 2 of Set 3 | atbasar
# Processing Record 3 of Set 3 | hua hin
# Processing Record 4 of Set 3 | namatanai
# Processing Record 5 of Set 3 | chara
# Processing Record 6 of Set 3 | ulvik
# Processing Record 7 of Set 3 | san juan bautista
# Processing Record 8 of Set 3 | omboue
# Processing Record 9 of Set 3 | oussouye
# Processing Record 10 of Set 3 | husavik
# Processing Record 11 of Set 3 | vesele
# Processing Record 12 of Set 3 | peniche
# Processing Record 13 of Set 3 | butaritari
# Processing Record 14 of Set 3 | saldanha
# Processing Record 15 of Set 3 | lahaina
# Processing Record 16 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 17 of Set 3 | aklavik
# Processing Record 18 of Set 3 | huicungo
# Processing Record 19 of Set 3 | hervey bay
# Processing Record 20 of Set 3 | port hardy
# Processing Record 21 of Set 3 | tuktoyaktuk
# Processing Record 22 of Set 3 | havre-saint-pierre
# Processing Record 23 of Set 3 | bilibino
# Processing Record 24 of Set 3 | formoso do araguaia
# City not found. Skipping...
# Processing Record 25 of Set 3 | vila
# Processing Record 26 of Set 3 | vaitupu
# City not found. Skipping...
# Processing Record 27 of Set 3 | comarapa
# Processing Record 28 of Set 3 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 29 of Set 3 | praya
# Processing Record 30 of Set 3 | marsa matruh
# Processing Record 31 of Set 3 | caninde
# Processing Record 32 of Set 3 | protvino
# Processing Record 33 of Set 3 | fare
# Processing Record 34 of Set 3 | mantua
# Processing Record 35 of Set 3 | lebu
# Processing Record 36 of Set 3 | port alfred
# Processing Record 37 of Set 3 | beira
# Processing Record 38 of Set 3 | muhos
# Processing Record 39 of Set 3 | iberia
# Processing Record 40 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 41 of Set 3 | moose factory
# Processing Record 42 of Set 3 | huntsville
# Processing Record 43 of Set 3 | bambous virieux
# Processing Record 44 of Set 3 | kavieng
# Processing Record 45 of Set 3 | airai
# Processing Record 46 of Set 3 | mundra
# Processing Record 47 of Set 3 | palmer
# Processing Record 48 of Set 3 | qingyuan
# Processing Record 49 of Set 3 | lavrentiya
# Processing Record 50 of Set 3 | poum
# Processing Record 1 of Set 4 | elko
# Processing Record 2 of Set 4 | puerto maldonado
# Processing Record 3 of Set 4 | longyearbyen
# Processing Record 4 of Set 4 | sola
# Processing Record 5 of Set 4 | bulgan
# Processing Record 6 of Set 4 | porosozero
# Processing Record 7 of Set 4 | saint-philippe
# Processing Record 8 of Set 4 | malpura
# Processing Record 9 of Set 4 | touros
# Processing Record 10 of Set 4 | robertsport
# Processing Record 11 of Set 4 | corowa
# Processing Record 12 of Set 4 | orzhytsya
# Processing Record 13 of Set 4 | hambantota
# Processing Record 14 of Set 4 | palana
# Processing Record 15 of Set 4 | iskateley
# Processing Record 16 of Set 4 | berlevag
# Processing Record 17 of Set 4 | vardo
# Processing Record 18 of Set 4 | san jeronimo
# Processing Record 19 of Set 4 | makakilo city
# Processing Record 20 of Set 4 | kolpashevo
# Processing Record 21 of Set 4 | chagda
# City not found. Skipping...
# Processing Record 22 of Set 4 | danilov
# Processing Record 23 of Set 4 | vanimo
# Processing Record 24 of Set 4 | umm lajj
# Processing Record 25 of Set 4 | vestmannaeyjar
# Processing Record 26 of Set 4 | tacuarembo
# Processing Record 27 of Set 4 | khatanga
# Processing Record 28 of Set 4 | sept-iles
# Processing Record 29 of Set 4 | pisco
# Processing Record 30 of Set 4 | duvan
# Processing Record 31 of Set 4 | cabo san lucas
# Processing Record 32 of Set 4 | pevek
# Processing Record 33 of Set 4 | carnarvon
# Processing Record 34 of Set 4 | umzimvubu
# City not found. Skipping...
# Processing Record 35 of Set 4 | nanortalik
# Processing Record 36 of Set 4 | pietarsaari
# Processing Record 37 of Set 4 | tual
# Processing Record 38 of Set 4 | loubomo
# Processing Record 39 of Set 4 | nara
# Processing Record 40 of Set 4 | talnakh
# Processing Record 41 of Set 4 | vestmanna
# Processing Record 42 of Set 4 | kruisfontein
# Processing Record 43 of Set 4 | sisimiut
# Processing Record 44 of Set 4 | barentsburg
# City not found. Skipping...
# Processing Record 45 of Set 4 | lubbock
# Processing Record 46 of Set 4 | chokurdakh
# Processing Record 47 of Set 4 | lorengau
# Processing Record 48 of Set 4 | souillac
# Processing Record 49 of Set 4 | muswellbrook
# Processing Record 50 of Set 4 | toliary
# City not found. Skipping...
# Processing Record 1 of Set 5 | monterey
# Processing Record 2 of Set 5 | belmonte
# Processing Record 3 of Set 5 | hasaki
# Processing Record 4 of Set 5 | dikson
# Processing Record 5 of Set 5 | goldsboro
# Processing Record 6 of Set 5 | sinnamary
# Processing Record 7 of Set 5 | taoudenni
# Processing Record 8 of Set 5 | chateaubelair
# Processing Record 9 of Set 5 | bom jesus do itabapoana
# Processing Record 10 of Set 5 | oga
# Processing Record 11 of Set 5 | shibetsu
# Processing Record 12 of Set 5 | calama
# Processing Record 13 of Set 5 | beyneu
# Processing Record 14 of Set 5 | gorno-chuyskiy
# City not found. Skipping...
# Processing Record 15 of Set 5 | maceio
# Processing Record 16 of Set 5 | camacari
# Processing Record 17 of Set 5 | jega
# Processing Record 18 of Set 5 | sal rei
# Processing Record 19 of Set 5 | port antonio
# Processing Record 20 of Set 5 | methala
# Processing Record 21 of Set 5 | te anau
# Processing Record 22 of Set 5 | teberda
# Processing Record 23 of Set 5 | conceicao do araguaia
# Processing Record 24 of Set 5 | port blair
# Processing Record 25 of Set 5 | sitka
# Processing Record 26 of Set 5 | kaitangata
# Processing Record 27 of Set 5 | vagur
# Processing Record 28 of Set 5 | barrow
# Processing Record 29 of Set 5 | faya
# Processing Record 30 of Set 5 | bara
# Processing Record 31 of Set 5 | esperance
# Processing Record 32 of Set 5 | yulara
# Processing Record 33 of Set 5 | sao filipe
# Processing Record 34 of Set 5 | tuatapere
# Processing Record 35 of Set 5 | lagos
# Processing Record 36 of Set 5 | yeppoon
# Processing Record 37 of Set 5 | itarema
# Processing Record 38 of Set 5 | clyde river
# Processing Record 39 of Set 5 | provideniya
# Processing Record 40 of Set 5 | ribeira grande
# Processing Record 41 of Set 5 | puerto escondido
# Processing Record 42 of Set 5 | viligili
# City not found. Skipping...
# Processing Record 43 of Set 5 | nantucket
# Processing Record 44 of Set 5 | mahaicony
# City not found. Skipping...
# Processing Record 45 of Set 5 | toro
# Processing Record 46 of Set 5 | yerofey pavlovich
# Processing Record 47 of Set 5 | presidencia roque saenz pena
# Processing Record 48 of Set 5 | baruun-urt
# Processing Record 49 of Set 5 | saint-francois
# Processing Record 50 of Set 5 | comodoro rivadavia
# Processing Record 1 of Set 6 | chatellerault
# Processing Record 2 of Set 6 | wulanhaote
# City not found. Skipping...
# Processing Record 3 of Set 6 | mys shmidta
# City not found. Skipping...
# Processing Record 4 of Set 6 | lagoa
# Processing Record 5 of Set 6 | culaman
# Processing Record 6 of Set 6 | nishihara
# Processing Record 7 of Set 6 | yerbogachen
# Processing Record 8 of Set 6 | coquimbo
# Processing Record 9 of Set 6 | pacific grove
# Processing Record 10 of Set 6 | bixby
# Processing Record 11 of Set 6 | ratnagiri
# Processing Record 12 of Set 6 | kavaratti
# Processing Record 13 of Set 6 | krasnyy yar
# Processing Record 14 of Set 6 | denpasar
# Processing Record 15 of Set 6 | bengkulu
# Processing Record 16 of Set 6 | ust-barguzin
# Processing Record 17 of Set 6 | kiunga
# Processing Record 18 of Set 6 | nouadhibou
# Processing Record 19 of Set 6 | rawson
# Processing Record 20 of Set 6 | porto novo
# Processing Record 21 of Set 6 | casablanca
# Processing Record 22 of Set 6 | jalu
# Processing Record 23 of Set 6 | dabola
# Processing Record 24 of Set 6 | jardim
# Processing Record 25 of Set 6 | tame
# Processing Record 26 of Set 6 | ayer itam
# City not found. Skipping...
# Processing Record 27 of Set 6 | genhe
# Processing Record 28 of Set 6 | jumla
# Processing Record 29 of Set 6 | aksha
# Processing Record 30 of Set 6 | kokologo
# Processing Record 31 of Set 6 | jaisalmer
# Processing Record 32 of Set 6 | nata
# Processing Record 33 of Set 6 | ilulissat
# Processing Record 34 of Set 6 | mabaruma
# Processing Record 35 of Set 6 | henties bay
# Processing Record 36 of Set 6 | ponta do sol
# Processing Record 37 of Set 6 | constitucion
# Processing Record 38 of Set 6 | severo-kurilsk
# Processing Record 39 of Set 6 | teguldet
# Processing Record 40 of Set 6 | dormidontovka
# Processing Record 41 of Set 6 | kumukh
# Processing Record 42 of Set 6 | rodino
# Processing Record 43 of Set 6 | bargal
# City not found. Skipping...
# Processing Record 44 of Set 6 | margate
# Processing Record 45 of Set 6 | shellbrook
# Processing Record 46 of Set 6 | salalah
# Processing Record 47 of Set 6 | acapulco
# Processing Record 48 of Set 6 | tiksi
# Processing Record 49 of Set 6 | san patricio
# Processing Record 50 of Set 6 | dangriga
# Processing Record 1 of Set 7 | marienburg
# Processing Record 2 of Set 7 | east london
# Processing Record 3 of Set 7 | hamilton
# Processing Record 4 of Set 7 | south sioux city
# Processing Record 5 of Set 7 | svetlaya
# Processing Record 6 of Set 7 | gawler
# Processing Record 7 of Set 7 | lasa
# Processing Record 8 of Set 7 | saint anthony
# Processing Record 9 of Set 7 | tasiilaq
# Processing Record 10 of Set 7 | haren
# Processing Record 11 of Set 7 | porangatu
# Processing Record 12 of Set 7 | akyab
# Processing Record 13 of Set 7 | budakalasz
# Processing Record 14 of Set 7 | thompson
# Processing Record 15 of Set 7 | ambulu
# Processing Record 16 of Set 7 | miandrivazo
# Processing Record 17 of Set 7 | bozova
# Processing Record 18 of Set 7 | borogontsy
# Processing Record 19 of Set 7 | sao felix do xingu
# Processing Record 20 of Set 7 | sorong
# Processing Record 21 of Set 7 | chumikan
# Processing Record 22 of Set 7 | kerki
# City not found. Skipping...
# Processing Record 23 of Set 7 | mogadishu
# Processing Record 24 of Set 7 | bahia blanca
# Processing Record 25 of Set 7 | bowen
# Processing Record 26 of Set 7 | mahebourg
# Processing Record 27 of Set 7 | kapaa
# Processing Record 28 of Set 7 | paita
# Processing Record 29 of Set 7 | great yarmouth
# Processing Record 30 of Set 7 | saskylakh
# Processing Record 31 of Set 7 | innisfail
# Processing Record 32 of Set 7 | nongan
# Processing Record 33 of Set 7 | guia lopes da laguna
# Processing Record 34 of Set 7 | itambacuri
# Processing Record 35 of Set 7 | macaubas
# Processing Record 36 of Set 7 | walvis bay
# Processing Record 37 of Set 7 | hanmer springs
# Processing Record 38 of Set 7 | rockport
# Processing Record 39 of Set 7 | los llanos de aridane
# Processing Record 40 of Set 7 | kushiro
# Processing Record 41 of Set 7 | mosquera
# Processing Record 42 of Set 7 | luderitz
# Processing Record 43 of Set 7 | general roca
# Processing Record 44 of Set 7 | tilichiki
# Processing Record 45 of Set 7 | hornepayne
# Processing Record 46 of Set 7 | eganville
# Processing Record 47 of Set 7 | rio gallegos
# Processing Record 48 of Set 7 | deep river
# Processing Record 49 of Set 7 | mazamari
# Processing Record 50 of Set 7 | jutai
# Processing Record 1 of Set 8 | east wenatchee bench
# Processing Record 2 of Set 8 | rothes
# Processing Record 3 of Set 8 | shingu
# Processing Record 4 of Set 8 | zyryanka
# Processing Record 5 of Set 8 | okhotsk
# Processing Record 6 of Set 8 | nachingwea
# Processing Record 7 of Set 8 | magaria
# Processing Record 8 of Set 8 | millinocket
# Processing Record 9 of Set 8 | nome
# Processing Record 10 of Set 8 | bubaque
# Processing Record 11 of Set 8 | amapa
# Processing Record 12 of Set 8 | chuy
# Processing Record 13 of Set 8 | cap-aux-meules
# Processing Record 14 of Set 8 | viedma
# Processing Record 15 of Set 8 | pringsewu
# Processing Record 16 of Set 8 | dzialdowo
# Processing Record 17 of Set 8 | inyonga
# Processing Record 18 of Set 8 | vauvert
# Processing Record 19 of Set 8 | bonfim
# Processing Record 20 of Set 8 | upernavik
# Processing Record 21 of Set 8 | kupang
# Processing Record 22 of Set 8 | capitan bado
# Processing Record 23 of Set 8 | clinton
# Processing Record 24 of Set 8 | babanusah
# City not found. Skipping...
# Processing Record 25 of Set 8 | aitape
# Processing Record 26 of Set 8 | skibbereen
# Processing Record 27 of Set 8 | qaqortoq
# Processing Record 28 of Set 8 | rehoboth
# Processing Record 29 of Set 8 | kirakira
# Processing Record 30 of Set 8 | bethel
# Processing Record 31 of Set 8 | kahului
# Processing Record 32 of Set 8 | kabinda
# Processing Record 33 of Set 8 | marcona
# City not found. Skipping...
# Processing Record 34 of Set 8 | grootfontein
# Processing Record 35 of Set 8 | cidreira
# Processing Record 36 of Set 8 | bac lieu
# Processing Record 37 of Set 8 | fortuna
# Processing Record 38 of Set 8 | bose
# Processing Record 39 of Set 8 | college
# Processing Record 40 of Set 8 | prince rupert
# Processing Record 41 of Set 8 | trinidad
# Processing Record 42 of Set 8 | halalo
# City not found. Skipping...
# Processing Record 43 of Set 8 | summerside
# Processing Record 44 of Set 8 | hurghada
# Processing Record 45 of Set 8 | badoc
# Processing Record 46 of Set 8 | bad oldesloe
# Processing Record 47 of Set 8 | diego de almagro
# Processing Record 48 of Set 8 | bud
# Processing Record 49 of Set 8 | kushima
# Processing Record 50 of Set 8 | nikolskoye
# Processing Record 1 of Set 9 | nakama
# Processing Record 2 of Set 9 | mankono
# Processing Record 3 of Set 9 | praskoveya
# Processing Record 4 of Set 9 | rio grande
# Processing Record 5 of Set 9 | flinders
# Processing Record 6 of Set 9 | fort nelson
# Processing Record 7 of Set 9 | sirjan
# Processing Record 8 of Set 9 | dembi dolo
# Processing Record 9 of Set 9 | bayan
# Processing Record 10 of Set 9 | cherskiy
# Processing Record 11 of Set 9 | dongtai
# Processing Record 12 of Set 9 | gotsu
# Processing Record 13 of Set 9 | oranjemund
# Processing Record 14 of Set 9 | manassas
# Processing Record 15 of Set 9 | shubarshi
# Processing Record 16 of Set 9 | tura
# Processing Record 17 of Set 9 | longlac
# City not found. Skipping...
# Processing Record 18 of Set 9 | klaeng
# Processing Record 19 of Set 9 | aktash
# Processing Record 20 of Set 9 | kokoda
# Processing Record 21 of Set 9 | pemagatsel
# Processing Record 22 of Set 9 | wucheng
# Processing Record 23 of Set 9 | maibong
# Processing Record 24 of Set 9 | labrea
# Processing Record 25 of Set 9 | chute-aux-outardes
# Processing Record 26 of Set 9 | ossora
# Processing Record 27 of Set 9 | yanchukan
# City not found. Skipping...
# Processing Record 28 of Set 9 | cockburn harbour
# City not found. Skipping...
# Processing Record 29 of Set 9 | iracoubo
# Processing Record 30 of Set 9 | hastings
# Processing Record 31 of Set 9 | jubayl
# City not found. Skipping...
# Processing Record 32 of Set 9 | labuhan
# Processing Record 33 of Set 9 | chernyshevskiy
# Processing Record 34 of Set 9 | fairbanks
# Processing Record 35 of Set 9 | lompoc
# Processing Record 36 of Set 9 | teguise
# Processing Record 37 of Set 9 | ayan
# Processing Record 38 of Set 9 | codrington
# Processing Record 39 of Set 9 | quatre cocos
# Processing Record 40 of Set 9 | poya
# Processing Record 41 of Set 9 | nemuro
# Processing Record 42 of Set 9 | valparaiso
# Processing Record 43 of Set 9 | ixtapa
# Processing Record 44 of Set 9 | mount isa
# Processing Record 45 of Set 9 | port-gentil
# Processing Record 46 of Set 9 | aksarka
# Processing Record 47 of Set 9 | tarko-sale
# Processing Record 48 of Set 9 | port elizabeth
# Processing Record 49 of Set 9 | tiarei
# Processing Record 50 of Set 9 | petropavlovsk-kamchatskiy
# Processing Record 1 of Set 10 | chahal
# Processing Record 2 of Set 10 | alofi
# Processing Record 3 of Set 10 | ust-nera
# Processing Record 4 of Set 10 | itarantim
# Processing Record 5 of Set 10 | batagay-alyta
# Processing Record 6 of Set 10 | viru
# Processing Record 7 of Set 10 | bukama
# Processing Record 8 of Set 10 | yatou
# Processing Record 9 of Set 10 | le port
# Processing Record 10 of Set 10 | merauke
# Processing Record 11 of Set 10 | alberton
# Processing Record 12 of Set 10 | castro
# Processing Record 13 of Set 10 | biskamzha
# Processing Record 14 of Set 10 | dawei
# Processing Record 15 of Set 10 | dalvik
# Processing Record 16 of Set 10 | camacha
# Processing Record 17 of Set 10 | betioky
# Processing Record 18 of Set 10 | havoysund
# Processing Record 19 of Set 10 | petatlan
# Processing Record 20 of Set 10 | srednekolymsk
# Processing Record 21 of Set 10 | shache
# Processing Record 22 of Set 10 | saleaula
# City not found. Skipping...
# Processing Record 23 of Set 10 | asau
# Processing Record 24 of Set 10 | boyolangu
# Processing Record 25 of Set 10 | dien bien
# City not found. Skipping...
# Processing Record 26 of Set 10 | penticton
# Processing Record 27 of Set 10 | nuuk
# Processing Record 28 of Set 10 | kolokani
# Processing Record 29 of Set 10 | fontem
# Processing Record 30 of Set 10 | tres arroyos
# Processing Record 31 of Set 10 | hoquiam
# Processing Record 32 of Set 10 | sorland
# Processing Record 33 of Set 10 | mahibadhoo
# Processing Record 34 of Set 10 | alice springs
# Processing Record 35 of Set 10 | roald
# Processing Record 36 of Set 10 | malwan
# City not found. Skipping...
# Processing Record 37 of Set 10 | umm durman
# City not found. Skipping...
# Processing Record 38 of Set 10 | dunedin
# Processing Record 39 of Set 10 | coxim
# Processing Record 40 of Set 10 | loralai
# Processing Record 41 of Set 10 | saint-louis
# Processing Record 42 of Set 10 | arman
# Processing Record 43 of Set 10 | manzil jamil
# City not found. Skipping...
# Processing Record 44 of Set 10 | shu
# Processing Record 45 of Set 10 | kincardine
# Processing Record 46 of Set 10 | grindavik
# Processing Record 47 of Set 10 | imbituba
# Processing Record 48 of Set 10 | manzanillo
# Processing Record 49 of Set 10 | guadalajara
# Processing Record 50 of Set 10 | ngukurr
# City not found. Skipping...
# Processing Record 1 of Set 11 | novaya malykla
# Processing Record 2 of Set 11 | dalhousie
# Processing Record 3 of Set 11 | raudeberg
# Processing Record 4 of Set 11 | moron
# Processing Record 5 of Set 11 | biloela
# Processing Record 6 of Set 11 | tabiauea
# City not found. Skipping...
# Processing Record 7 of Set 11 | mormugao
# Processing Record 8 of Set 11 | kloulklubed
# Processing Record 9 of Set 11 | suoyarvi
# Processing Record 10 of Set 11 | vilyuysk
# Processing Record 11 of Set 11 | coahuayana
# Processing Record 12 of Set 11 | baiao
# Processing Record 13 of Set 11 | tigzirt
# Processing Record 14 of Set 11 | beringovskiy
# Processing Record 15 of Set 11 | atambua
# Processing Record 16 of Set 11 | karratha
# Processing Record 17 of Set 11 | flin flon
# Processing Record 18 of Set 11 | bereda
# Processing Record 19 of Set 11 | pathein
# Processing Record 20 of Set 11 | pulsano
# Processing Record 21 of Set 11 | yazman
# Processing Record 22 of Set 11 | haines junction
# Processing Record 23 of Set 11 | faridpur
# Processing Record 24 of Set 11 | chake chake
# Processing Record 25 of Set 11 | centerville
# Processing Record 26 of Set 11 | mahon
# Processing Record 27 of Set 11 | pangnirtung
# Processing Record 28 of Set 11 | goundam
# Processing Record 29 of Set 11 | balkanabat
# Processing Record 30 of Set 11 | nungua
# Processing Record 31 of Set 11 | lerwick
# Processing Record 32 of Set 11 | san marcos
# Processing Record 33 of Set 11 | mae hong son
# Processing Record 34 of Set 11 | korla
# Processing Record 35 of Set 11 | birao
# Processing Record 36 of Set 11 | wewak
# Processing Record 37 of Set 11 | seoul
# Processing Record 38 of Set 11 | torrington
# Processing Record 39 of Set 11 | pontianak
# Processing Record 40 of Set 11 | hovd
# Processing Record 41 of Set 11 | puerto cabezas
# Processing Record 42 of Set 11 | tawkar
# City not found. Skipping...
# Processing Record 43 of Set 11 | lucapa
# Processing Record 44 of Set 11 | aswan
# Processing Record 45 of Set 11 | tevaitoa
# Processing Record 46 of Set 11 | saint-joseph
# Processing Record 47 of Set 11 | kamenka
# Processing Record 48 of Set 11 | parkes
# Processing Record 49 of Set 11 | kampot
# Processing Record 50 of Set 11 | kasongo-lunda
# Processing Record 1 of Set 12 | kautokeino
# Processing Record 2 of Set 12 | bintulu
# Processing Record 3 of Set 12 | puerto padre
# Processing Record 4 of Set 12 | nicoya
# Processing Record 5 of Set 12 | ucluelet
# Processing Record 6 of Set 12 | ojinaga
# Processing Record 7 of Set 12 | nola
# Processing Record 8 of Set 12 | adrar
# Processing Record 9 of Set 12 | ternate
# Processing Record 10 of Set 12 | sobolevo
# Processing Record 11 of Set 12 | taltal
# Processing Record 12 of Set 12 | kalomo
# City not found. Skipping...
# Processing Record 13 of Set 12 | olafsvik
# Processing Record 14 of Set 12 | tucuma
# Processing Record 15 of Set 12 | padang
# Processing Record 16 of Set 12 | itum-kale
# Processing Record 17 of Set 12 | narsaq
# Processing Record 18 of Set 12 | plouzane
# Processing Record 19 of Set 12 | qandala
# Processing Record 20 of Set 12 | centralia
# Processing Record 21 of Set 12 | malakal
# Processing Record 22 of Set 12 | dauphin
# Processing Record 23 of Set 12 | kaduqli
# Processing Record 24 of Set 12 | vila franca do campo
# Processing Record 25 of Set 12 | powell
# Processing Record 26 of Set 12 | divnogorsk
# Processing Record 27 of Set 12 | masallatah
# Processing Record 28 of Set 12 | cap malheureux
# Processing Record 29 of Set 12 | angoche
# Processing Record 30 of Set 12 | sayyan
# Processing Record 31 of Set 12 | novyy svit
# Processing Record 32 of Set 12 | nangong
# Processing Record 33 of Set 12 | halifax
# Processing Record 34 of Set 12 | kapoeta
# Processing Record 35 of Set 12 | namibe
# Processing Record 36 of Set 12 | along
# Processing Record 37 of Set 12 | loreto
# Processing Record 38 of Set 12 | herat
# Processing Record 39 of Set 12 | dubbo
# Processing Record 40 of Set 12 | razdolinsk
# Processing Record 41 of Set 12 | pilikwe
# Processing Record 42 of Set 12 | muisne
# Processing Record 43 of Set 12 | richards bay
# Processing Record 44 of Set 12 | saint-leu
# Processing Record 45 of Set 12 | sabang
# Processing Record 46 of Set 12 | meulaboh
# Processing Record 47 of Set 12 | guane
# Processing Record 48 of Set 12 | husum
# Processing Record 49 of Set 12 | aykhal
# Processing Record 50 of Set 12 | mayo
# Processing Record 1 of Set 13 | daru
# Processing Record 2 of Set 13 | ponta delgada
# Processing Record 3 of Set 13 | lata
# Processing Record 4 of Set 13 | kirensk
# Processing Record 5 of Set 13 | mathathane
# Processing Record 6 of Set 13 | mocambique
# City not found. Skipping...
# Processing Record 7 of Set 13 | illapel
# Processing Record 8 of Set 13 | hami
# Processing Record 9 of Set 13 | shumskiy
# Processing Record 10 of Set 13 | linqu
# Processing Record 11 of Set 13 | landeck
# Processing Record 12 of Set 13 | kudahuvadhoo
# Processing Record 13 of Set 13 | tromso
# Processing Record 14 of Set 13 | tukrah
# Processing Record 15 of Set 13 | linfen
# Processing Record 16 of Set 13 | kalemie
# Processing Record 17 of Set 13 | muli
# Processing Record 18 of Set 13 | gumdag
# Processing Record 19 of Set 13 | tsybli
# Processing Record 20 of Set 13 | luanda
# Processing Record 21 of Set 13 | ahuimanu
# Processing Record 22 of Set 13 | avera
# Processing Record 23 of Set 13 | lolua
# City not found. Skipping...
# Processing Record 24 of Set 13 | saint-pierre
# Processing Record 25 of Set 13 | komsomolets
# Processing Record 26 of Set 13 | carutapera
# Processing Record 27 of Set 13 | canico
# Processing Record 28 of Set 13 | bardiyah
# Processing Record 29 of Set 13 | dezhou
# Processing Record 30 of Set 13 | talara
# Processing Record 31 of Set 13 | mugur-aksy
# Processing Record 32 of Set 13 | bathsheba
# Processing Record 33 of Set 13 | hualmay
# Processing Record 34 of Set 13 | anloga
# Processing Record 35 of Set 13 | zeya
# Processing Record 36 of Set 13 | saint-georges
# Processing Record 37 of Set 13 | cockburn town
# Processing Record 38 of Set 13 | nador
# Processing Record 39 of Set 13 | egvekinot
# Processing Record 40 of Set 13 | pimentel
# Processing Record 41 of Set 13 | jiayuguan
# Processing Record 42 of Set 13 | mozarlandia
# Processing Record 43 of Set 13 | komsomolskiy
# Processing Record 44 of Set 13 | krasnoselkup
# Processing Record 45 of Set 13 | san cristobal
# Processing Record 46 of Set 13 | beloha
# Processing Record 47 of Set 13 | kasama
# Processing Record 48 of Set 13 | ceyhan
# Processing Record 49 of Set 13 | azoyu
# Processing Record 50 of Set 13 | tautira
# Processing Record 1 of Set 14 | antalaha
# Processing Record 2 of Set 14 | tomari
# Processing Record 3 of Set 14 | kieta
# Processing Record 4 of Set 14 | salym
# Processing Record 5 of Set 14 | amboasary
# Processing Record 6 of Set 14 | port hedland
# Processing Record 7 of Set 14 | deputatskiy
# Processing Record 8 of Set 14 | pochutla
# Processing Record 9 of Set 14 | garoua
# Processing Record 10 of Set 14 | polson
# Processing Record 11 of Set 14 | severodvinsk
# Processing Record 12 of Set 14 | iroquois falls
# Processing Record 13 of Set 14 | marsh harbour
# Processing Record 14 of Set 14 | mandalgovi
# Processing Record 15 of Set 14 | crestview
# Processing Record 16 of Set 14 | xining
# Processing Record 17 of Set 14 | phonhong
# Processing Record 18 of Set 14 | yomitan
# City not found. Skipping...
# Processing Record 19 of Set 14 | bull savanna
# Processing Record 20 of Set 14 | bafata
# Processing Record 21 of Set 14 | tomatlan
# Processing Record 22 of Set 14 | makung
# City not found. Skipping...
# Processing Record 23 of Set 14 | ushibuka
# Processing Record 24 of Set 14 | caceres
# Processing Record 25 of Set 14 | pierre
# Processing Record 26 of Set 14 | bridlington
# Processing Record 27 of Set 14 | kizema
# Processing Record 28 of Set 14 | lakatoro
# Processing Record 29 of Set 14 | cotonou
# Processing Record 30 of Set 14 | baisha
# Processing Record 31 of Set 14 | lilongwe
# Processing Record 32 of Set 14 | norsup
# Processing Record 33 of Set 14 | qui nhon
# Processing Record 34 of Set 14 | kuche
# City not found. Skipping...
# Processing Record 35 of Set 14 | malmesbury
# Processing Record 36 of Set 14 | elesbao veloso
# Processing Record 37 of Set 14 | kununurra
# Processing Record 38 of Set 14 | talwandi bhai
# Processing Record 39 of Set 14 | beipiao
# Processing Record 40 of Set 14 | aripuana
# Processing Record 41 of Set 14 | lianran
# Processing Record 42 of Set 14 | sioux lookout
# Processing Record 43 of Set 14 | suna
# Processing Record 44 of Set 14 | haibowan
# City not found. Skipping...
# Processing Record 45 of Set 14 | rodrigues alves
# Processing Record 46 of Set 14 | bacuit
# City not found. Skipping...
# Processing Record 47 of Set 14 | yichun
# Processing Record 48 of Set 14 | bembereke
# Processing Record 49 of Set 14 | port shepstone
# Processing Record 50 of Set 14 | monte alegre
# Processing Record 1 of Set 15 | kez
# Processing Record 2 of Set 15 | aanekoski
# Processing Record 3 of Set 15 | sangin
# Processing Record 4 of Set 15 | sorvag
# City not found. Skipping...
# Processing Record 5 of Set 15 | ust-omchug
# Processing Record 6 of Set 15 | fallon
# Processing Record 7 of Set 15 | havelock
# Processing Record 8 of Set 15 | acarau
# Processing Record 9 of Set 15 | morwa
# Processing Record 10 of Set 15 | ladario
# Processing Record 11 of Set 15 | cayeli
# Processing Record 12 of Set 15 | pokrovsk
# Processing Record 13 of Set 15 | tiznit
# Processing Record 14 of Set 15 | yasu
# Processing Record 15 of Set 15 | marawi
# Processing Record 16 of Set 15 | leshukonskoye
# Processing Record 17 of Set 15 | bay roberts
# Processing Record 18 of Set 15 | moree
# Processing Record 19 of Set 15 | lerik
# Processing Record 20 of Set 15 | kuybyshevo
# Processing Record 21 of Set 15 | barcelos
# Processing Record 22 of Set 15 | tkvarcheli
# City not found. Skipping...
# Processing Record 23 of Set 15 | laredo
# Processing Record 24 of Set 15 | aljezur
# Processing Record 25 of Set 15 | prieska
# Processing Record 26 of Set 15 | urumqi
# Processing Record 27 of Set 15 | sharjah
# Processing Record 28 of Set 15 | wadi musa
# Processing Record 29 of Set 15 | nowy sacz
# Processing Record 30 of Set 15 | fort collins
# Processing Record 31 of Set 15 | merced
# Processing Record 32 of Set 15 | smolyaninovo
# Processing Record 33 of Set 15 | nyurba
# Processing Record 34 of Set 15 | mehamn
# Processing Record 35 of Set 15 | tabas
# Processing Record 36 of Set 15 | dakar
# Processing Record 37 of Set 15 | skerries
# Processing Record 38 of Set 15 | salinopolis
# Processing Record 39 of Set 15 | palu
# Processing Record 40 of Set 15 | rabo de peixe
# Processing Record 41 of Set 15 | nam tha
# City not found. Skipping...
# Processing Record 42 of Set 15 | kamiichi
# Processing Record 43 of Set 15 | camrose
# Processing Record 44 of Set 15 | kuching
# Processing Record 45 of Set 15 | arona
# Processing Record 46 of Set 15 | victoria point
# Processing Record 47 of Set 15 | esna
# Processing Record 48 of Set 15 | zhezkazgan
# Processing Record 49 of Set 15 | ivolginsk
# Processing Record 50 of Set 15 | pangai
# Processing Record 1 of Set 16 | aflu
# City not found. Skipping...
# Processing Record 2 of Set 16 | coruripe
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df
# Out:
#            City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Jamestown      US  42.0970  -79.2353     69.12        97          90
# 1       Iqaluit      CA  63.7506  -68.5145     43.70        65          75
# 2       Guaruja      BR -23.9931  -46.2564     77.07        52          75
# 3    Bredasdorp      ZA -34.5322   20.0403     51.12        82          55
# 4         Vaini      TO -21.2000 -175.2000     75.36        88          75
# ..          ...     ...      ...       ...       ...       ...         ...
# 690        Esna      EG  25.2934   32.5540     78.82        37           0
# 691  Zhezkazgan      KZ  47.8043   67.7144     43.27        78          99
# 692   Ivolginsk      RU  51.7492  107.2837     35.26        93          90
# 693      Pangai      TO -19.8000 -174.3500     77.11        73          75
# 694    Coruripe      BR -10.1256  -36.1756     76.28        85          10
#
#      Wind Speed Current Description
# 0          5.99                mist
# 1          8.57       broken clouds
# 2          3.44       moderate rain
# 3          3.44       broken clouds
# 4         10.36       broken clouds
# ..          ...                 ...
# 690       15.14           clear sky
# 691        7.16     overcast clouds
# 692        2.24     overcast clouds
# 693       20.71       broken clouds
# 694       12.10           clear sky
#
# [695 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_Database.csv"

# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label = "City_ID")
